# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hist2d = [ 0 for i in range(5000) ]
with open('./g_hist2d.txt', 'r') as f:
    for i, l in enumerate(f.readlines()):
        hist2d[i] = list( map(int, l.split(',')) )

# %%
X_range = len(hist2d)
Y_range = len(hist2d[0])

X = list(range(X_range))
Y = list(range(Y_range))


COLOR_HIST = [ [0 for y in Y] for x in X ]

for i, line in enumerate(COLOR_HIST):
    for j, col in enumerate(line):
        COLOR_HIST[i][j] = hist2d[i][j]

# %%
fig, ax = plt.subplots( 1,1, figsize=(150,100) )

ax.imshow( np.array(hist2d).T, cmap='hot')

# %%
plt.plot(hist2d[200])

# %%
np.linspace(80,120,200)
# Out:
# array([  80.        ,   80.20100503,   80.40201005,   80.60301508,
#          80.8040201 ,   81.00502513,   81.20603015,   81.40703518,
#          81.6080402 ,   81.80904523,   82.01005025,   82.21105528,
#          82.4120603 ,   82.61306533,   82.81407035,   83.01507538,
#          83.2160804 ,   83.41708543,   83.61809045,   83.81909548,
#          84.0201005 ,   84.22110553,   84.42211055,   84.62311558,
#          84.8241206 ,   85.02512563,   85.22613065,   85.42713568,
#          85.6281407 ,   85.82914573,   86.03015075,   86.23115578,
#          86.4321608 ,   86.63316583,   86.83417085,   87.03517588,
#          87.2361809 ,   87.43718593,   87.63819095,   87.83919598,
#          88.04020101,   88.24120603,   88.44221106,   88.64321608,
#          88.84422111,   89.04522613,   89.24623116,   89.44723618,
#          89.64824121,   89.84924623,   90.05025126,   90.25125628,
#          90.45226131,   90.65326633,   90.85427136,   91.05527638,
#          91.25628141,   91.45728643,   91.65829146,   91.85929648,
#          92.06030151,   92.26130653,   92.46231156,   92.66331658,
#          92.86432161,   93.06532663,   93.26633166,   93.46733668,
#          93.66834171,   93.86934673,   94.07035176,   94.27135678,
#          94.47236181,   94.67336683,   94.87437186,   95.07537688,
#          95.27638191,   95.47738693,   95.67839196,   95.87939698,
#          96.08040201,   96.28140704,   96.48241206,   96.68341709,
#          96.88442211,   97.08542714,   97.28643216,   97.48743719,
#          97.68844221,   97.88944724,   98.09045226,   98.29145729,
#          98.49246231,   98.69346734,   98.89447236,   99.09547739,
#          99.29648241,   99.49748744,   99.69849246,   99.89949749,
#         100.10050251,  100.30150754,  100.50251256,  100.70351759,
#         100.90452261,  101.10552764,  101.30653266,  101.50753769,
#         101.70854271,  101.90954774,  102.11055276,  102.31155779,
#         102.51256281,  102.71356784,  102.91457286,  103.11557789,
#         103.31658291,  103.51758794,  103.71859296,  103.91959799,
#         104.12060302,  104.32160804,  104.52261307,  104.72361809,
#         104.92462312,  105.12562814,  105.32663317,  105.52763819,
#         105.72864322,  105.92964824,  106.13065327,  106.33165829,
#         106.53266332,  106.73366834,  106.93467337,  107.13567839,
#         107.33668342,  107.53768844,  107.73869347,  107.93969849,
#         108.14070352,  108.34170854,  108.54271357,  108.74371859,
#         108.94472362,  109.14572864,  109.34673367,  109.54773869,
#         109.74874372,  109.94974874,  110.15075377,  110.35175879,
#         110.55276382,  110.75376884,  110.95477387,  111.15577889,
#         111.35678392,  111.55778894,  111.75879397,  111.95979899,
#         112.16080402,  112.36180905,  112.56281407,  112.7638191 ,
#         112.96482412,  113.16582915,  113.36683417,  113.5678392 ,
#         113.76884422,  113.96984925,  114.17085427,  114.3718593 ,
#         114.57286432,  114.77386935,  114.97487437,  115.1758794 ,
#         115.37688442,  115.57788945,  115.77889447,  115.9798995 ,
#         116.18090452,  116.38190955,  116.58291457,  116.7839196 ,
#         116.98492462,  117.18592965,  117.38693467,  117.5879397 ,
#         117.78894472,  117.98994975,  118.19095477,  118.3919598 ,
#         118.59296482,  118.79396985,  118.99497487,  119.1959799 ,
#         119.39698492,  119.59798995,  119.79899497,  120.        ])

# %%
plt.plot(np.histogram([np.random.normal() for i in range(1000000)])[0])

# %%
[np.random.normal() for i in range(1000)]
# Out:
# -0.4394020906674719
